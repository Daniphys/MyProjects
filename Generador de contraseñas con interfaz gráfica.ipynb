# %%
#Intento con Radiobutton
from tkinter import *
from tkinter import messagebox
import string 
import random
raiz=Tk()
raiz.title("Generador de contraseñas")
#raiz.iconbitmap("pollo.ico")
raiz.config(bg="#ACC2C1")
miFrame=Frame(raiz) #El frame formara parte de la raíz
miFrame.pack()
miFrame.config(bg="#338BF4")
#------Variables para imprimir resultado y realizar el programa-----#
Opcion=IntVar()
password_generada=()
password_generada=StringVar()
#-------Caracteristicas para el generador de contraseñas------#
caract1=list(string.ascii_letters)
caract2=list(string.digits)
caract3=list("°!#$%&/=?¡*¨-_|+}]¿")
#-----función para extraer datos 
#----Generador de contraseñas---#
def Imprimir():
    if Opcion.get()==1:
        for i in range(int(longitud.get())):
            password_generada=[random.choice(caract2)]
            resultado.insert(0,password_generada)
    elif Opcion.get()==2:
        for i in range(int(longitud.get())):
            password_generada=[random.choice(caract1)]
            resultado.insert(0,password_generada)
    elif Opcion.get()==3:
        for i in range(int(longitud.get())):
            password_generada=[random.choice(caract3)]
            resultado.insert(0,password_generada)
    elif Opcion.get()==4:
        for i in range(int(longitud.get())):
            password_generada=[random.choice((caract2+caract1))]
            resultado.insert(0,password_generada)
    elif Opcion.get()==5:
        for i in range(int(longitud.get())):
            password_generada=[random.choice((caract2+caract3))]
            resultado.insert(0,password_generada)
    elif Opcion.get()==6:
        for i in range(int(longitud.get())):
            password_generada=[random.choice((caract1+caract3))]
            resultado.insert(0,password_generada)
    elif Opcion.get()==7:
        for i in range(int(longitud.get())):
            password_generada=[random.choice((caract1+caract2+caract3))]
            resultado.insert(0,password_generada)

        
#-------------Función para mostrar contraseña------------#
#def mostrar():
    #password_generada.set(password_generada.get())

#------Texto introductorio y además se le indica al usuario las instrucciones para generar la contraseña deseada------#

introduction=Label(miFrame, text="Bienvenido al generador de contraseñas", fg="red", font=("Arial", 12, "bold")).grid(row=0,column=1,padx=10,pady=10, columnspan=4)
introduction=Label(miFrame, text="Escoge la opción que quieras para tu contraseña", fg="black", font=("Arial", 12)).grid(row=1,column=1,padx=10,pady=10, columnspan=4)
#--------------fila1------------------#

boton123=Radiobutton(miFrame, text="123", width=20, value=1, variable=Opcion) 
boton123.grid(row=2, column=1) 
boton_abc=Radiobutton(miFrame, text="aBc", width=20, value=2, variable=Opcion)
boton_abc.grid(row=2, column=2)
boton_special=Radiobutton(miFrame, text="!$%", width=20, value=3, variable=Opcion)
boton_special.grid(row=2, column=3)


#--------------fila2------------------#

boton_numabc=Radiobutton(miFrame, text="123 y aBc", width=20, value=4, variable=Opcion) 
boton_numabc.grid(row=3, column=1) #posicionamiento de botones
boton_numspe=Radiobutton(miFrame, text="123 y !$%", width=20, value=5, variable=Opcion)
boton_numspe.grid(row=3, column=2)
boton_abcspe=Radiobutton(miFrame, text="aBc y !$%", width=20, value=6, variable=Opcion)
boton_abcspe.grid(row=3, column=3)


#--------------fila3------------------#

boton_all=Radiobutton(miFrame, text="123, aBc y !$%", width=20, value=7, variable=Opcion) 
boton_all.grid(row=4, column=2) 

#------Longitud de contraseña----------#
longitud=Entry(miFrame, width=20) 
longitud.grid(row=6, column=2) 
nombreLabel=Label(miFrame, text="Longitud de la contraseña:", width=20)
nombreLabel.grid(row=6,column=1)
boton_generar=Button(miFrame, text="Generar Contraseña", width=20, command=Imprimir) 
boton_generar.grid(row=6, column=3)
#-----------------Pantalla--------------------#
resultado=Entry(miFrame, width=20)
resultado.grid(row=7,column=2)
resultado.config(background="white", fg="black", justify="right") #Utilizamos codigos de colores
nombreLabel=Label(miFrame, text="Contraseña Generada: ", width=20)
nombreLabel.grid(row=7,column=1)



raiz.mainloop()
